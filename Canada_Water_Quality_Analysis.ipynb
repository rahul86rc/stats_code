# %%
import pandas as pd
import numpy as np

# %%
water_qual = pd.read_excel("D:\learnbay\statistics_git\stats_code\Water-Qual-Eau-Sites-National.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26048/1853771070.py in <module>
# ----> 1 water_qual = pd.read_excel("D:\learnbay\statistics_git\stats_code\Water-Qual-Eau-Sites-National.xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
water_qual.head()
# Out:
#    SITE_NO                                          SITE_NAME  \
# 0       72  BEAUHARNOIS CANAL AT RTE 132 BRIDGE IN VALLEYF...
# 1       75  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...
# 2       78  ST.LAWRENCE RIVER WATER INTAKE AT THE WATER PL...
# 3  2330001   ETCHEMIN RIVER AT BRIDGE - RTE 132 IN ST-ROMUALD
# 4  2340033  CHAUDIÈRE RIVER AT CHARNY WATER INTAKE - 5.6 K...
#
#                                          SITE_NOM_FR      SITE_TYPE SITE_DESC  \
# 0  CANAL DE BEAUHARNOIS AU PONT-ROUTE 132 À VALLE...  RIVER/RIVIÈRE       NaN
# 1  FLEUVE SAINT-LAURENT À LA PRISE D'EAU DE L'USI...  RIVER/RIVIÈRE       NaN
# 2  FLEUVE SAINT-LAURENT À LA PRISE D'EAU DE L'USI...  RIVER/RIVIÈRE       NaN
# 3  RIVIÈRE ETCHEMIN AU PONT-ROUTE 132 À SAINT-ROM...  RIVER/RIVIÈRE       NaN
# 4  RIVIÈRE CHAUDIÈRE À LA PRISE D'EAU DE CHARNY À...  RIVER/RIVIÈRE       NaN
#
#   SITE_DESC_FR   LATITUDE  LONGITUDE  DATUM PROV_TERR      PEARSEDA  \
# ...

# %%
water_qual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SITE_NO       371 non-null    object
#  1   SITE_NAME     371 non-null    object
#  2   SITE_NOM_FR   366 non-null    object
#  3   SITE_TYPE     371 non-null    object
#  4   SITE_DESC     84 non-null     object
#  5   SITE_DESC_FR  71 non-null     object
#  6   LATITUDE      371 non-null    float64
#  7   LONGITUDE     371 non-null    float64
#  8   DATUM         371 non-null    object
#  9   PROV_TERR     371 non-null    object
#  10  PEARSEDA      371 non-null    object
#  11  PEARSEDA_FR   371 non-null    object
#  12  OCEANDA       371 non-null    object
#  13  OCEANDA_FR    371 non-null    object
#  14  DATA_URL      115 non-null    object
#  15  DATA_URL_FR   115 non-null    object
# dtypes: float64(2), object(14)
# memory usage: 46.5+ KB
